# %% [markdown]
# ## Punto Tres.
#
# Sea $P(t)$ la población de cierta especie en un parque natural, con $t$
# tiempo en años y $P$ en miles. La ecuación diferencial
#
# $$
# \frac{dP}{dt}=P(P-1)(2-P)
# $$
#
# describe la tasa de cambio de la población de la especie en el instante
# $t$.
#
# a.  Realice el diagrama de fase para la ecuación diferencial.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t, P):
    return P * (P - 1) * (2 - P)

h = 0.25
m = np.arange(0, 41)
n = np.arange(0, 13)

T, P = np.meshgrid(m*h, n*h)

pendiente = f(T, P)

norm = np.sqrt(1 + pendiente**2)

U = 1 / norm
V = pendiente / norm

fig, ax = plt.subplots(figsize=(10, 6))

ax.quiver(T, P, U, V, angles='xy')

ax.set_xlim(0, 10)
ax.set_ylim(0, 3)

ax.set_xlabel('t (años)')
ax.set_ylabel('P (miles de ejemplares)')

ax.set_title('Campo direccional de dP/dt = P(P-1)(2-P)')

ax.axhline(1, linestyle='--')
ax.axhline(2, linestyle='--')

plt.show()

# %% [markdown]
# b.  Si la población inicial es de 3000 ejemplares, ¿qué se puede decir
#     acerca de la población después de mucho tiempo?
#
# ## b) Población inicial de 3000 ejemplares
#
# Como $P$ está expresada en miles:
#
# $$
# P(0)=3000/1000=3
# $$
#
# Como:
#
# $$
# P>2
# $$
#
# tenemos que:
#
# $$
# \frac{dP}{dt}<0
# $$
#
# Por lo tanto, la población disminuye y se aproxima al equilibrio $P=2$.
#
# Entonces:
#
# $$
# \lim_{t\rightarrow\infty}P(t)=2
# $$
#
# Es decir, después de mucho tiempo la población se aproxima a:
#
# $$
# \boxed{2000\text{ ejemplares}}
# $$
# Despues de mucho tiempo, la poblacion se aproxima a 2000 ejemplares.
#
# c.  ¿Qué ocurre si la población inicial es de 1500?
#
# ## c) Población inicial de 1500 ejemplares
#
# La población inicial en miles es:
#
# $$
# P(0)=1.5
# $$
#
# Como:
#
# $$
# 1<P<2
# $$
#
# tenemos:
#
# $$
# \frac{dP}{dt}>0
# $$
#
# Por lo tanto, la población aumenta.
#
# La población se aproxima al equilibrio estable:
#
# $$
# P=2
# $$
#
# Por lo tanto:
#
# $$
# \boxed{2000\text{ ejemplares}}
# $$
#
# La poblacion aumenta y se aproxima a 2000 ejemplares
#
# d.  ¿Cuál es el comportamiento de la población, si inicialmente había
#     500 ejemplares?
#
#
# La población inicial en miles es:
#
# $$
# P(0)=0.5
# $$
#
# Como:
#
# $$
# 0<P<1
# $$
#
# tenemos:
#
# $$
# \frac{dP}{dt}<0
# $$
#
# Por lo tanto, la población disminuye.
#
# La población se aproxima al equilibrio:
#
# $$
# P=0
# $$
#
# Por lo tanto, a largo plazo:
#
# $$
# \boxed{0\text{ ejemplares}}
# $$
#
# La poblacion disminuye progresivamente y tiende a 0 ejemplares.
#
# e.  ¿Puede una población inicial de 900 ejemplares crecer hasta 1100?
#
# ## e) ¿Puede una población inicial de 900 ejemplares crecer hasta 1100?
#
# La población inicial es:
#
# $$
# P(0)=0.9
# $$
#
# Y queremos saber si puede llegar a:
#
# $$
# P=1.1
# $$
#
# Como:
#
# $$
# 0<P<1
# $$
#
# tenemos:
#
# $$
# \frac{dP}{dt}<0
# $$
#
# Por lo tanto, la población está disminuyendo, no aumentando.
#
# Además, $P=1$ (1000 ejemplares) es un punto de equilibrio inestable.
#
# Por lo tanto, una población de 900 ejemplares no puede crecer hasta 1100.
#
# $$
# \boxed{\text{No, no puede crecer hasta 1100 ejemplares.}}
# $$
